# %%
from sqlalchemy.engine import URL
from sqlalchemy import create_engine, text, MetaData, Table

db_url = URL.create(
    drivername="mysql+pymysql",
    username="teamx",
    password="#C!D123^-c12",
    host="112.125.88.107",
    port=5906,
    database="TeamX_BIGAI",
    query={"charset": "utf8mb4"},
)

# db_url = URL.create(
#     drivername="mysql+pymysql",
#     username="agentictrl",
#     password="`1qaz~!QAZ",
#     host="112.125.88.107",
#     port=5906,
#     database="BIGAI",
#     query={"charset": "utf8mb4"},
# )

engine = create_engine(db_url, pool_pre_ping=True)

# %%
metadata = MetaData()

# 反射全部表结构
metadata.reflect(bind=engine)

print("数据库 BIGAI 包含以下表：")
for tbl in metadata.sorted_tables:
    print(f"\n🗂  table：{tbl.name}")
    for col in tbl.columns:
        print(f"   - {col.name} ({col.type}) {'PK' if col.primary_key else ''}")
# Out:
# 数据库 BIGAI 包含以下表：
#
# 🗂  表：checkpoint
#    - id (BIGINT) PK
#    - name (VARCHAR(50))
#    - version (VARCHAR(50))
#    - run_id (VARCHAR(191))
#    - status (VARCHAR(20))
#    - path (VARCHAR(255))
#    - source (VARCHAR(50))
#    - operator (VARCHAR(50))
#    - remark (VARCHAR(1024))
#    - config_yaml (TEXT)
#    - created_at (TIMESTAMP)
#    - updated_at (TIMESTAMP)
#    - deleted_at (TIMESTAMP)
#    - started_at (TIMESTAMP)
#    - finished_at (TIMESTAMP)
#
# 🗂  表：current_model
#    - id (BIGINT) PK
#    - checkpoint_id (BIGINT)
#    - version (VARCHAR(50))
#    - path (VARCHAR(255))
#    - status (VARCHAR(20))
#    - created_at (TIMESTAMP)
#    - updated_at (TIMESTAMP)
#    - activated_by (VARCHAR(50))
#    - remark (VARCHAR(1024))
#
# 🗂  表：dataset_usage_events
#    - id (BIGINT) PK
#    - trajectory_id (VARCHAR(128) COLLATE "utf8mb4_unicode_ci")
#    - run_id (VARCHAR(128) COLLATE "utf8mb4_unicode_ci")
#    - model_version (VARCHAR(512) COLLATE "utf8mb4_unicode_ci")
#    - used_delta (INTEGER)
#    - event_type (ENUM)
#    - created_at (TIMESTAMP)
#
# 🗂  表：datasets
#    - id (INTEGER) PK
#    - trajectory_id (VARCHAR(255))
#    - created_at (TIMESTAMP)
#    - used (INTEGER)
#    - model_version (VARCHAR(64))
#    - run_id (VARCHAR(255))
#    - task_id (VARCHAR(255))
#    - reward (FLOAT)
#
# 🗂  表：inference_node
#    - id (BIGINT) PK
#    - pod_name (VARCHAR(50))
#    - model_registry_id (BIGINT)
#    - status (VARCHAR(20))
#    - remark (VARCHAR(255))
#    - started_at (TIMESTAMP)
#    - updated_at (TIMESTAMP)
#    - deleted_at (TIMESTAMP)
#    - task_id (VARCHAR(64))
#
# 🗂  表：inference_tasks
#    - id (INTEGER) PK
#    - task_id (VARCHAR(64))
#    - statefulset_base_name (VARCHAR(50))
#    - statefulset_name (VARCHAR(100))
#    - namespace (VARCHAR(50))
#    - batch_size (INTEGER)
#    - replicas (INTEGER)
#    - gpu_count (INTEGER)
#    - loop_interval_seconds (INTEGER)
#    - pod_ready_timeout_seconds (INTEGER)
#    - graceful_shutdown_timeout (INTEGER)
#    - termination_grace_period (INTEGER)
#    - created_at (TIMESTAMP)
#    - updated_at (TIMESTAMP)
#    - deleted_at (TIMESTAMP)
#    - status (ENUM)
#
# 🗂  表：model_registry
#    - id (BIGINT) PK
#    - task_id (VARCHAR(64))
#    - name (VARCHAR(50))
#    - version (VARCHAR(255))
#    - status (VARCHAR(20))
#    - path (VARCHAR(255))
#    - source (VARCHAR(50))
#    - operator (VARCHAR(50))
#    - remark (VARCHAR(1024))
#    - config_yaml (TEXT)
#    - created_at (TIMESTAMP)
#    - updated_at (TIMESTAMP)
#    - deleted_at (TIMESTAMP)
#    - type (VARCHAR(20))
#    - replicas (INTEGER)
#    - gpu_per_replica (INTEGER)
#
# 🗂  表：rollout_run
#    - id (BIGINT) PK
#    - run_id (VARCHAR(191) COLLATE "utf8mb4_unicode_ci")
#    - trajectory_id (VARCHAR(191) COLLATE "utf8mb4_unicode_ci")
#    - task_id (VARCHAR(191) COLLATE "utf8mb4_unicode_ci")
#    - trace_id (VARCHAR(191) COLLATE "utf8mb4_unicode_ci")
#    - split_dir (VARCHAR(512) COLLATE "utf8mb4_unicode_ci")
#    - reward (DOUBLE)
#    - num_chunks (INTEGER)
#    - used (INTEGER)
#    - model_version (VARCHAR(512) COLLATE "utf8mb4_unicode_ci")
#    - instruction (VARCHAR(1024) COLLATE "utf8mb4_unicode_ci")
#    - create_at (TIMESTAMP)
#
# 🗂  表：trainable_group
#    - id (BIGINT)
#    - trajectory_id (VARCHAR(191) COLLATE "utf8mb4_unicode_ci") PK
#    - task_id (VARCHAR(191) COLLATE "utf8mb4_unicode_ci")
#    - reward (DOUBLE)
#    - model_version (VARCHAR(191) COLLATE "utf8mb4_unicode_ci")
#    - create_at (DATETIME)
#    - run_id (VARCHAR(191) COLLATE "utf8mb4_unicode_ci")
#
# 🗂  表：update_model_task
#    - id (BIGINT) PK
#    - checkpoint_id (BIGINT)
#    - path (VARCHAR(255))
#    - version (VARCHAR(50))
#    - type (VARCHAR(20))
#    - status (TINYINT)
#    - priority (TINYINT)
#    - created_at (TIMESTAMP)
#    - updated_at (TIMESTAMP)
#    - started_at (TIMESTAMP)
#    - completed_at (TIMESTAMP)
#    - remark (VARCHAR(1024))
#
# 🗂  表：rollout_chunk
#    - trajectory_id (VARCHAR(191) COLLATE "utf8mb4_unicode_ci")
#    - run_id (VARCHAR(191) COLLATE "utf8mb4_unicode_ci")
#    - chunk_index (INTEGER)
#    - id (BIGINT) PK
#    - json_path (VARCHAR(512) COLLATE "utf8mb4_unicode_ci")

# %%
# run_id="results/pass8_20250919_trainset181_gpu4_env40_vllm_logp_maxstep30_osworld_new"
# run_id="results/ablation_novllm_logp_pass8_20250920_trainset45_gpu2_env20_vllm_logp_maxstep30_osworld_new"

run_id="results/ablation_logp_pass8_20250920_trainset45_gpu2_env20_vllm_logp_maxstep30_osworld_new"
# run_id="results/test_trainset_26_plan"
# run_id="results/trainset181_pass8_gpu4_env38_maxstep30_tmp1_osworldnew_20250918_1130"
# run_id="results/trainset181_pass8_gpu4_env38_maxstep30_tmp1_osworldnew_20250918_1130"
run_id="results/resume_ablation_logp_pass8_20250920_trainset45_gpu2_env20_vllm_logp_maxstep30_osworld_new"
run_id="results/trainset214_pass8_gpu4_env38_maxstep30_tmp1_20250922_2124"
with engine.connect() as conn:
    result = conn.execute(text(f"SELECT count(*) as count, avg(num_chunks) as avg_chunks, avg(reward) as avg_reward, count(distinct task_id) as unique_task_count, model_version FROM `rollout_run` where run_id='{run_id}' group by model_version ORDER BY min(id)"))
    rows = result.mappings().all()   # list[dict]，便于后续处理
print(f"rollout_run 共 {len(rows)} 行")


import pandas as pd
from IPython.display import display
# 可选：转成 DataFrame 方便查看
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):
    display(pd.DataFrame(rows))
    pd.DataFrame(rows).to_csv("rollout_run_model_version_stats.csv", index=False)
# Out:
# rollout_run 共 82 行
#    avg_chunks  avg_reward  count  \
# 0     15.1270    0.489914    638
# 1     14.1576    0.555479    311
# 2     17.3843    0.471283    268
# 3     17.5093    0.531002    324
# 4     15.3885    0.655336    314
# 5     11.0308    0.651189    195
# 6     14.8472    0.488960    373
# 7     14.8799    0.510078    358
# 8     17.8144    0.517807    291
# 9     15.6565    0.546780   2434
# 10    13.3844    0.642347    320
# 11    17.9080    0.522989    174
# 12    13.5268    0.592280    298
# 13    13.9585    0.555249    265
# 14    13.6911    0.540246    246
# 15    14.1617    0.604255    235
# 16    14.8903    0.464059    237
# 17    12.5120    0.594830    250
# 18    16.1492    0.515841    248
# 19    14.3975    0.612459    239
# 20    11.3146    0.603977    267
# 21    13.1117    0.590329    188
# 22    14.5415    0.430521    205
# 23    14.4305    0.587444    223
# 24    12.4304    0.605140    316
# 25    13.3566    0.557887    244
# 26    12.7455    0.652265    279
# 27    12.1775    0.593221    231
# 28    13.4268    0.581570    239
# 29    16.1345    0.494780    238
# 30    16.5180    0.562579    222
# 31    12.7216    0.660564    291
# 32    13.5833    0.553333    300
# 33    15.2237    0.519863    219
# 34    12.9926    0.603916    270
# 35    15.7822    0.571816    225
# 36    14.1790    0.616395    257
# 37    13.8919    0.602247    259
# 38    14.7842    0.670567    278
# 39    13.9695    0.557316    295
# 40    14.2971    0.642229    276
# 41    12.5978    0.634438    271
# 42    15.4885    0.579526    260
# 43    11.3492    0.664754    358
# 44    15.2092    0.531720    282
# 45    15.0586    0.569125   2766
# 46    13.5769    0.626693    286
# 47    14.7401    0.551409    227
# 48    13.0223    0.672191    314
# 49    13.2601    0.614752    346
# 50    13.9735    0.622485    377
# 51    14.9947    0.476050    377
# 52    12.1097    0.682309    310
# 53    13.6456    0.544071    364
# 54    12.3774    0.634058    310
# 55    13.1014    0.599078    217
# 56    15.9195    0.509123    261
# 57    13.4369    0.585108    325
# 58    13.2835    0.577985    321
# 59    12.7688    0.594269    320
# 60    14.8190    0.610794    232
# 61    15.6929    0.532882    267
# 62    14.1622    0.627315   1319
# 63    14.3428    0.575972    283
# 64    13.8652    0.720997    282
# 65    12.6205    0.682037    332
# 66    13.4768    0.596026    302
# 67    15.9300    0.570303    243
# 68    13.4128    0.667785    298
# 69    13.1329    0.739872    301
# 70    12.0594    0.698276    202
# 71    15.8180    0.485801    401
# 72    13.0231    0.699705    303
# 73    13.0897    0.663677    234
# 74    14.4304    0.705779    230
# 75    12.8500    0.720067    360
# 76    14.1658    0.638936   3371
# 77    14.2298    0.585123    322
# 78    12.9198    0.642296    237
# 79    11.8693    0.696113    283
# 80    14.9920    0.673307    251
# 81    13.2968    0.660527    283
#
#                                                                                                                                                                                   model_version  \
# 0                                                                                                                 /capacity/userdata/vcfenxd75jiv/shichenrui/ui_tars/ByteDance-Seed/UI-TARS-1.5
# 1    /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_1/actor/huggingface
# 2    /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_2/actor/huggingface
# 3    /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_3/actor/huggingface
# 4    /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_4/actor/huggingface
# 5    /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_5/actor/huggingface
# 6    /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_6/actor/huggingface
# 7    /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_7/actor/huggingface
# 8    /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_8/actor/huggingface
# 9    /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_9/actor/huggingface
# 10  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_10/actor/huggingface
# 11  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_11/actor/huggingface
# 12  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_12/actor/huggingface
# 13  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_13/actor/huggingface
# 14  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_14/actor/huggingface
# 15  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_15/actor/huggingface
# 16  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_16/actor/huggingface
# 17  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_17/actor/huggingface
# 18  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_18/actor/huggingface
# 19  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_19/actor/huggingface
# 20  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_20/actor/huggingface
# 21  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_21/actor/huggingface
# 22  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_22/actor/huggingface
# 23  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_23/actor/huggingface
# 24  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_24/actor/huggingface
# 25  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_25/actor/huggingface
# 26  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_26/actor/huggingface
# 27  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_27/actor/huggingface
# 28  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_28/actor/huggingface
# 29  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_29/actor/huggingface
# 30  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_30/actor/huggingface
# 31  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_31/actor/huggingface
# 32  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_32/actor/huggingface
# 33  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_33/actor/huggingface
# 34  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_34/actor/huggingface
# 35  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_35/actor/huggingface
# 36  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_36/actor/huggingface
# 37  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_37/actor/huggingface
# 38  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_38/actor/huggingface
# 39  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_39/actor/huggingface
# 40  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_40/actor/huggingface
# 41  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_41/actor/huggingface
# 42  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_42/actor/huggingface
# 43  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_43/actor/huggingface
# 44  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_44/actor/huggingface
# 45  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_45/actor/huggingface
# 46  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_46/actor/huggingface
# 47  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_47/actor/huggingface
# 48  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_48/actor/huggingface
# 49  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_49/actor/huggingface
# 50  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_50/actor/huggingface
# 51  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_51/actor/huggingface
# 52  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_52/actor/huggingface
# 53  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_53/actor/huggingface
# 54  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_54/actor/huggingface
# 55  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_55/actor/huggingface
# 56  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_56/actor/huggingface
# 57  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_57/actor/huggingface
# 58  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_58/actor/huggingface
# 59  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_59/actor/huggingface
# 60  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_60/actor/huggingface
# 61  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_61/actor/huggingface
# 62  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_62/actor/huggingface
# 63  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_63/actor/huggingface
# 64  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_64/actor/huggingface
# 65  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_65/actor/huggingface
# 66  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_66/actor/huggingface
# 67  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_67/actor/huggingface
# 68  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_68/actor/huggingface
# 69  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_69/actor/huggingface
# 70  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_70/actor/huggingface
# 71  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_71/actor/huggingface
# 72  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_72/actor/huggingface
# 73  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_73/actor/huggingface
# 74  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_74/actor/huggingface
# 75  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_75/actor/huggingface
# 76  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_76/actor/huggingface
# 77  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_77/actor/huggingface
# 78  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_78/actor/huggingface
# 79  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_79/actor/huggingface
# 80  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_80/actor/huggingface
# 81  /workspace/computer-use/verl/checkpoints/verl_osworld_grpo/async_pass8_train214_lr1e-6_bz8_minibs128_downsample_stepwise_kl_maxstep30_logp_gspo_osworldnew/global_step_81/actor/huggingface
#
#     unique_task_count
# 0                  82
# 1                  41
# 2                  37
# 3                  44
# 4                  42
# 5                  31
# 6                  50
# 7                  51
# 8                  39
# 9                 211
# 10                 43
# 11                 27
# 12                 40
# 13                 37
# 14                 35
# 15                 33
# 16                 34
# 17                 36
# 18                 35
# 19                 34
# 20                 40
# 21                 27
# 22                 32
# 23                 33
# 24                 43
# 25                 36
# 26                 39
# 27                 31
# 28                 34
# 29                 35
# 30                 31
# 31                 41
# 32                 39
# 33                 31
# 34                 39
# 35                 34
# 36                 34
# 37                 37
# 38                 38
# 39                 41
# 40                 38
# 41                 37
# 42                 38
# 43                 50
# 44                 40
# 45                214
# 46                 43
# 47                 31
# 48                 42
# 49                 44
# 50                 51
# 51                 51
# 52                 44
# 53                 45
# 54                 45
# 55                 32
# 56                 37
# 57                 44
# 58                 44
# 59                 43
# 60                 34
# 61                 36
# 62                138
# 63                 41
# 64                 39
# 65                 47
# 66                 40
# 67                 36
# 68                 41
# 69                 42
# 70                 37
# 71                 52
# 72                 47
# 73                 35
# 74                 31
# 75                 48
# 76                214
# 77                 42
# 78                 33
# 79                 38
# 80                 35
# 81                 39

# %%
# results/pass16_20250901_train15_pass16_gpu2_env20_vllm_logp_maxstep15

# results/pass16_20250901_train15_pass16_gpu2_env20_vllm_logp_maxstep15

# %%
import pandas as pd

# 查看run_id已采样的数据
# run_id="results/test_for_train_pass8_gpu7_env69_20250821_2333" # results/test_for_train_instruction  results/pass@32_trainset90
# run_id="results/pass8_20250913_trainset152_gpu6_env58_vllm_logp_maxstep30_node2" # results/test_for_train_instruction  results/pass@32_trainset90
# run_id="results/trainset181_pass8_gpu4_env38_maxstep30_tmp1_osworldnew_20250918_1130"
run_id = ""
with engine.connect() as conn:
    result = conn.execute(text(f"SELECT * FROM `rollout_run` where run_id='{run_id}' order by create_at desc"))
    rows = result.mappings().all()   # list[dict]，便于后续处理
print(f"rollout_run 共 {len(rows)} 行")
# 可选：转成 DataFrame 方便查看
df = pd.DataFrame(rows)
if "task_id" in df.columns and "reward" in df.columns:
    avg_rewards = df.groupby("task_id")["reward"].mean()
    traj_counts = df.groupby("task_id")["trajectory_id"].nunique()
    summary_df = pd.DataFrame({
        "avg_reward": avg_rewards,
        "traj_count": traj_counts
    })
    print("每个 task 的统计：")
    with pd.option_context('display.max_rows', None, 'display.max_columns', None):
        display(summary_df)
else:
    print("数据中缺少 task_id 或 reward 字段")


import pandas as pd; pd.DataFrame(rows)
# Out:
# rollout_run 共 0 行
# 数据中缺少 task_id 或 reward 字段
# Empty DataFrame
# Columns: []
# Index: []

# %%
results/trainset181_pass8_gpu4_env38_maxstep30_tmp1_osworldnew_20250918_1130

# %%
# 查看run_id已保存的checkpoints
# run_id="results/pass16_20250902_train90_pass16_gpu2_env20_vllm_logp_maxstep50" # results/test_for_train_instruction  results/pass@32_trainset90
run_id="results/resume_ablation_logp_pass8_20250920_trainset45_gpu2_env20_vllm_logp_maxstep30_osworld_new"
with engine.connect() as conn:
    result = conn.execute(text("SELECT * FROM `checkpoint` where run_id = '{run_id}' "))
    rows = result.mappings().all()   # list[dict]，便于后续处理
print(f"checkpoint 共 {len(rows)} 行")
# 可选：转成 DataFrame 方便查看
# print(rows[0])
import pandas as pd; pd.DataFrame(rows).head()
# Out:
# checkpoint 共 0 行
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # 从rollout_run中删除某run_id的数据
# run_id="results/test_for_train_pass8_gpu7_env69_20250821_2333"
# with engine.begin() as conn:
#     will = conn.execute(
#         text("SELECT COUNT(*) FROM `rollout_run` WHERE `run_id` = :rid"),
#         {"rid": run_id}
#     ).scalar_one()
#     print(f"将删除 {will} 行（run_id = {run_id}）")
#
#     res = conn.execute(
#         text("DELETE FROM `rollout_run` WHERE `run_id` = :rid"),
#         {"rid": run_id}
#     )
#     print(f"✅ 已删除 {res.rowcount} 行")

# %%
# run_id="results/test_for_train_pass8_gpu8_env77_20250817_1345"
with engine.connect() as conn:
    cnt = conn.execute(
        text("""
            SELECT COUNT(*) FROM `rollout_run`
            WHERE `run_id` = :{run_id} AND `used` != 0
        """),
        {"rid": run_id},
    ).scalar_one()
print(f"确认 used!=0 的行数：{cnt}")

with engine.begin() as conn:
    res = conn.execute(
        text("""
            UPDATE `rollout_run`
            SET `used` = 0
            WHERE `run_id` = :{run_id}
        """),
        {"rid": run_id},
    )
    print(f"✅ 更新行数: {res.rowcount}")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/default.py:951, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     950 def do_execute(self, cursor, statement, parameters, context=None):
# --> 951     cursor.execute(statement, parameters)
#
# File ~/miniconda3/lib/python3.13/site-packages/pymysql/cursors.py:153, in Cursor.execute(self, query, args)
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#
# File ~/miniconda3/lib/python3.13/site-packages/pymysql/cursors.py:322, in Cursor._query(self, q)
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#
# File ~/miniconda3/lib/python3.13/site-packages/pymysql/connections.py:575, in Connection.query(self, sql, unbuffered)
#     574 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 575 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     576 return self._affected_rows
#
# File ~/miniconda3/lib/python3.13/site-packages/pymysql/connections.py:826, in Connection._read_query_result(self, unbuffered)
#     825 else:
# --> 826     result.read()
#     827 self._result = result
#
# File ~/miniconda3/lib/python3.13/site-packages/pymysql/connections.py:1203, in MySQLResult.read(self)
#    1202 try:
# -> 1203     first_packet = self.connection._read_packet()
#    1205     if first_packet.is_ok_packet():
#
# File ~/miniconda3/lib/python3.13/site-packages/pymysql/connections.py:782, in Connection._read_packet(self, packet_type)
#     781         self._result.unbuffered_active = False
# --> 782     packet.raise_for_error()
#     783 return packet
#
# File ~/miniconda3/lib/python3.13/site-packages/pymysql/protocol.py:219, in MysqlPacket.raise_for_error(self)
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File ~/miniconda3/lib/python3.13/site-packages/pymysql/err.py:150, in raise_mysql_exception(data)
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# ProgrammingError: (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near ':{run_id} AND `used` != 0' at line 2")
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[19], line 3
#       1 # run_id="results/test_for_train_pass8_gpu8_env77_20250817_1345"
#       2 with engine.connect() as conn:
# ----> 3     cnt = conn.execute(
#       4         text("""
#       5             SELECT COUNT(*) FROM `rollout_run`
#       6             WHERE `run_id` = :{run_id} AND `used` != 0
#       7         """),
#       8         {"rid": run_id},
#       9     ).scalar_one()
#      10 print(f"确认 used!=0 的行数：{cnt}")
#      12 with engine.begin() as conn:
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1419, in Connection.execute(self, statement, parameters, execution_options)
#    1417     raise exc.ObjectNotExecutableError(statement) from err
#    1418 else:
# -> 1419     return meth(
#    1420         self,
#    1421         distilled_parameters,
#    1422         execution_options or NO_OPTIONS,
#    1423     )
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/sql/elements.py:526, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     524     if TYPE_CHECKING:
#     525         assert isinstance(self, Executable)
# --> 526     return connection._execute_clauseelement(
#     527         self, distilled_params, execution_options
#     528     )
#     529 else:
#     530     raise exc.ObjectNotExecutableError(self)
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1641, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1629 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1630     "compiled_cache", self.engine._compiled_cache
#    1631 )
#    1633 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1634     dialect=dialect,
#    1635     compiled_cache=compiled_cache,
#    (...)   1639     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1640 )
# -> 1641 ret = self._execute_context(
#    1642     dialect,
#    1643     dialect.execution_ctx_cls._init_compiled,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     execution_options,
#    1647     compiled_sql,
#    1648     distilled_parameters,
#    1649     elem,
#    1650     extracted_params,
#    1651     cache_hit=cache_hit,
#    1652 )
#    1653 if has_events:
#    1654     self.dispatch.after_execute(
#    1655         self,
#    1656         elem,
#    (...)   1660         ret,
#    1661     )
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:2355, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2353 elif should_wrap:
#    2354     assert sqlalchemy_exception is not None
# -> 2355     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2356 else:
#    2357     assert exc_info[1] is not None
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1965                 break
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#    1972     self.dispatch.after_cursor_execute(
#    1973         self,
#    1974         cursor,
#    (...)   1978         context.executemany,
#    1979     )
#
# File ~/miniconda3/lib/python3.13/site-packages/sqlalchemy/engine/default.py:951, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     950 def do_execute(self, cursor, statement, parameters, context=None):
# --> 951     cursor.execute(statement, parameters)
#
# File ~/miniconda3/lib/python3.13/site-packages/pymysql/cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~/miniconda3/lib/python3.13/site-packages/pymysql/cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~/miniconda3/lib/python3.13/site-packages/pymysql/connections.py:575, in Connection.query(self, sql, unbuffered)
#     573     sql = sql.encode(self.encoding, "surrogateescape")
#     574 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 575 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     576 return self._affected_rows
#
# File ~/miniconda3/lib/python3.13/site-packages/pymysql/connections.py:826, in Connection._read_query_result(self, unbuffered)
#     824     result.init_unbuffered_query()
#     825 else:
# --> 826     result.read()
#     827 self._result = result
#     828 if result.server_status is not None:
#
# File ~/miniconda3/lib/python3.13/site-packages/pymysql/connections.py:1203, in MySQLResult.read(self)
#    1201 def read(self):
#    1202     try:
# -> 1203         first_packet = self.connection._read_packet()
#    1205         if first_packet.is_ok_packet():
#    1206             self._read_ok_packet(first_packet)
#
# File ~/miniconda3/lib/python3.13/site-packages/pymysql/connections.py:782, in Connection._read_packet(self, packet_type)
#     780     if self._result is not None and self._result.unbuffered_active is True:
#     781         self._result.unbuffered_active = False
# --> 782     packet.raise_for_error()
#     783 return packet
#
# File ~/miniconda3/lib/python3.13/site-packages/pymysql/protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File ~/miniconda3/lib/python3.13/site-packages/pymysql/err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# ProgrammingError: (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near ':{run_id} AND `used` != 0' at line 2")
# [SQL:
#             SELECT COUNT(*) FROM `rollout_run`
#             WHERE `run_id` = :{run_id} AND `used` != 0
#         ]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# 更新used = 0 数据的model version
run_id="results/pass@32_trainset90"
model_version = "/workspace/computer-use/verl/checkpoints/verl_osworld_grpo/osworld_all_feasible_reward_script_grpo_k8s_0813_h8zdohoq/global_step_10/actor/huggingface"
model_version = "/capacity/userdata/vcfenxd75jiv/shichenrui/ui_tars/ByteDance-Seed/UI-TARS-1.5"
with engine.connect() as conn:
    cnt, sample = conn.execute(
        text("""
            SELECT COUNT(*) AS cnt, MAX(`model_version`) AS sample_version
            FROM `rollout_run`
            WHERE `run_id` = :rid AND `used` = 0
        """),
        {"rid": run_id},
    ).one()
print(f"used=0 的剩余行数: {cnt}，示例版本: {sample}")

with engine.begin() as conn:
    res = conn.execute(
        text("""
            UPDATE `rollout_run`
            SET `model_version` = :mv
            WHERE `run_id` = :rid AND `used` = 0
        """),
        {"mv": model_version, "rid": run_id},
    )
    print(f"✅ 更新行数: {res.rowcount}")

# %%
# 统计run_id validation 结果

import numpy as np
import json
import pandas as pd
# val_trainset90_px_08220031_step10
# run_ids = ["results/val_train150_uitars_maxstep50", 
#            "results/val_trainset90_px_08220031_step10", 
#            "results/val_trainset90_px_08220031_step20", 
#            "results/val_trainset90_px_08220031_step30", 
#            "results/val_trainset90_px_08220031_step35",
#            "results/val_trainset90_px_08220031_step40"]
run_ids = ["results/pass16_20250825_train15_pass16_gpu4_env36_kl"]

with open("../evaluation_examples/test_trainset_15.json", "r", encoding="utf-8") as f:
    mapping = json.load(f)
eval_task_ids = set()
for _, lst in mapping.items():
    eval_task_ids.update(lst)
    
placeholders = ", ".join([f":id{i}" for i in range(len(run_ids))]) or ":id0"
sql = text(f"""
    SELECT reward, run_id, task_id
    FROM rollout_run
    WHERE run_id IN ({placeholders})
""")
params = {f"id{i}": rid for i, rid in enumerate(run_ids)} or {"id0": None}

with engine.begin() as conn:
    df = pd.read_sql(sql, conn, params=params)

def agg_by_run_id(df: pd.DataFrame) -> pd.DataFrame:
    x = df["reward"].fillna(0)
    reward_non_neg1 = np.where(x.eq(-1), 0, x).astype(float)

    df_calc = pd.DataFrame({
        "run_id": df["run_id"].values,
        "reward_non_neg1": reward_non_neg1
    })

    total_rows = df_calc.groupby("run_id").size().rename("total_rows")
    total_score = df_calc.groupby("run_id")["reward_non_neg1"].sum().rename("total_score")

    result = (
        pd.concat([total_rows, total_score], axis=1)
        .assign(success_rate=lambda d: d["total_score"] / d["total_rows"])
        .reset_index()
        .sort_values("run_id")
    )
    return result

df_subset = df[df["task_id"].isin(eval_task_ids)]
result_subset = agg_by_run_id(df).rename(columns={
    "metric": "metric_subset",
    "total_score": "total_score",
    "total_rows": "total_rows_subset",
})

result_subset

# %%
result_subset = agg_by_run_id(df_subset).rename(columns={
    "metric": "metric_subset",
    "total_score": "total_score",
    "total_rows": "total_rows_subset",
})
result_subset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 result_subset = agg_by_run_id(df_subset).rename(columns={
#       2     "metric": "metric_subset",
#       3     "total_score": "total_score",
#       4     "total_rows": "total_rows_subset",
#       5 })
#       6 result_subset
#
# NameError: name 'agg_by_run_id' is not defined
